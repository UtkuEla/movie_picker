# %% [markdown]
# ## Autocompletion
# Source: https://medium.com/@linuxadminhacks/creating-a-gui-autocomplete-app-with-tkinter-and-trie-tree-a066936aa17e

# %%
from tkinter import Tk, Entry, Listbox, END
from collections import defaultdict
import pandas as pd

# %%
# import movie parq file
movies = pd.read_parquet("../tmdb_api/tmdb_api_cleaned/movies_cleaned_hard.parquet")

# %%
class TrieNode:
    def __init__(self):
        self.children = defaultdict(TrieNode)
        self.is_word = False


class Trie:
    def __init__(self):
        self.root = TrieNode()

    def insert(self, word):
        node = self.root
        for char in word:
            node = node.children[char]
        node.is_word = True

    def search(self, prefix):
        node = self.root
        suggestions = []
        for char in prefix:
            if char not in node.children:
                return suggestions
            node = node.children[char]
        self._find_suggestions(node, prefix, suggestions)
        return suggestions

    def _find_suggestions(self, node, prefix, suggestions):
        if node.is_word:
            suggestions.append(prefix)
        for char, child in node.children.items():
            self._find_suggestions(child, prefix + char, suggestions)


def load_words(dataframe, column):
    words = set()
    f = dataframe[column]
    
    for line in f.astype(str):
        words.update(line.strip().split())
    return words


def update_suggestions(event, trie, entry, suggestions_listbox):
    prefix = entry.get()
    if not prefix:
        suggestions_listbox.delete(0, END)
        return
    suggestions = trie.search(prefix)
    suggestions_listbox.delete(0, END)
    for suggestion in suggestions:
        suggestions_listbox.insert(END, suggestion)


def main():
    words = load_words(movies, "director")  # Replace with your word file path
    print("Geladene Wörter:", words)  # Debugging

    trie = Trie()
    for word in words:
        trie.insert(word)

    root = Tk()
    root.title("Autocomplete App")

    entry = Entry(root)
    entry.pack(padx=10, pady=10)
    entry.bind("<KeyRelease>", lambda e: update_suggestions(e, trie, entry, suggestions_listbox))

    suggestions_listbox = Listbox(root, width=50)
    suggestions_listbox.pack(padx=10, pady=10)

    try:
        root.mainloop()
    except Exception as e:
        print("Fehler beim Starten der GUI:", e)

if __name__ == "__main__":
    main()
# Out:
# Geladene Wörter: {'Tamahori', 'Eduardo', 'Anderson', 'Byun', 'Chupack', 'Correy', 'Luc', 'Walker', 'Marian', 'Benson', 'Solomon', 'Matthijs', 'Silvera', 'González', 'Haskin', 'Bill', 'Meirelles', 'Eiichi', 'Aboyantz,', 'Trank', 'Declan', 'Caligari', 'Gerald', 'Moccia', 'Geda', 'Keishi', 'Bezucha', 'Marcus', 'Kren,', 'Noriyuki', 'Safdie,', 'Anna', 'Veber', 'Carey-Hill', 'Joy', 'Wojtowicz-Vosloo', 'Povenmire,', 'Baz', 'Mamoru', 'Dugan', 'Marnier', 'Sarafian', 'Katt', 'Bolger', 'Tykwer', 'Verneuil', 'Siu-Fai', 'Marsh', 'Markowitz', 'Leonard', 'Ambrossi', 'Megan', 'Slade', 'Martishius,', 'Hamri', 'Yasuto', 'Hernán', 'Wexler', 'Bong', 'Penelope', 'Yamaguchi,', 'Frant', 'Díaz', 'Daryl', 'Yamauchi', 'Stacchi', 'Meadows', 'Schenkman', 'Irwin', 'Carpenter', 'Cassar', 'Tomomi', 'Muriel', 'McKee,', 'Mayfield', 'Okuno,', 'Ducournau', 'Johannes', 'Bhansali', 'Korty', 'Bairéad', 'DuVall', 'Vincent,', 'Zako,', 'Horvath,', 'Hayes', 'Araki', 'Tatum,', 'Kimmy', 'Hahn', 'McGowan', 'Goyette', 'Zoya', 'Lewis', 'Barron', 'Savini', 'Coppola,', 'Fukunaga', 'Letterman,', 'Duffy', 'Luske,', 'Bruckman,', 'Gamze', 'Pablos', 'Maras', 'Kroyer', 'Schneider,', 'West,', 'Swinton', 'Yau', 'Everardo', 'Okada,', 'Wilfred', 'Stalberg', 'Whissell,', 'Faiman', 'Giannoli', 'Goldman', 'Choi', 'Koike', 'Rintaro', 'Takahiro', 'Kimo', 'Burton', 'Hashimoto', 'Towne', 'Sandel', 'Aukerman', 'Deodato', 'Blakeson', 'Egoyan', 'Webber', 'Maguire', 'Neugebauer', 'Evan', 'Werner', 'Potter', 'Kounen', 'Christo', 'Sophia', 'Mednikow', 'LaBute', 'Spiegel', 'Matthew', 'Myrick,', 'Jeannine', 'Brest', 'Skjoldbjærg', 'Emerald', 'Kinnane', 'Friedlander', 'Field', 'Tay', 'Oxide', 'Im', 'Kwan,', 'Onteniente', 'Glimcher', 'Masayuki', 'Nanni', 'Rachid', 'Luciano', 'Menéndez', 'Terruso', 'Lei', 'Clare', 'Satrapi,', 'Liza', 'Stokes,', 'İlker', 'Caton-Jones', 'Freeman', 'Ingmar', 'Bruckner,', 'Danielle', 'Philippou,', 'Gallo', 'Masahiro', 'Jeanne', 'Gato,', 'Jennie', 'Hallie', 'Speck', 'Cheol-soo', 'Gregory', 'Macy', 'Gábor', 'Bertolucci', 'Kerr', 'Talbot', 'Graves', 'Schindler', 'Chiwetel', 'Takács', 'Yury', 'Antin', 'Mostow', 'Reeve,', 'Masahiko', 'Clayton', 'Matsumoto,', 'Eléonore', 'Baran', 'Kobayashi', 'DeCubellis', 'Duffer,', 'Asif', 'Lazar', 'Marischka', 'Aoki,', 'Bettis,', 'Tonderai', 'Can', 'Cervera', 'Coolidge', 'Minnelli', 'Devlin', 'Milev', 'Ned', 'Kölsch,', 'Rohmer', 'Skipp,', 'Abramenko', 'Parra', 'Chantal', 'Jonah', 'Patrik', 'Giordana', 'Cortés', 'Bradbeer', 'MacIntyre,', 'Jensen', 'Tamura', 'Chen', 'Appel', 'Storm', 'Miyamoto', 'Stevenson', 'Peirce', 'Guillaume', 'Aniello', 'Lynn', 'Nadine', 'Bennett', 'Traill', 'Fargo', 'Hark', 'Davy', 'Elia', 'Benjamin', 'Jean-Jacques', 'Arthur', 'Tafdrup', 'Urushadze', 'Zack', 'Kunio', 'Rusty', 'Han-min', 'Cimino', 'Tatsuyuki', 'Felix', 'Katherine', 'Faruk', 'Wadlow', 'Fuchssteiner,', 'Daniela', 'Fragasso', 'Durand', 'Silverman', 'McKenna', 'Castille', 'Ferry', 'Boyle', 'Yunfei', 'Jayson', 'Wells', 'Snyder', 'Maya', 'Othenin-Girard', 'Leos', 'Hanggi', 'J', 'Ardolino', 'Marston', 'Shinya', 'Zito', 'Hyatt', 'Jones', 'Atom', 'Mancini', 'Fleischer', 'Peter', 'Majidi', 'Karey', 'Wilde', 'Sheldon', 'Tati', 'Tristan', 'Greenfield', 'Chloe', 'Bettinelli-Olpin,', 'Quane,', 'Tonino', 'Lucas', 'Noboru', 'Mizushima,', 'Westfeldt', 'Konzelman,', 'Chazelle', 'Fricke', 'Wolf', 'Levy', 'SK', 'Anurag', 'Godano', 'Thiessen', 'Stearns', 'Fidell', 'Tsang', 'Poyart', 'Dong-hyuk', 'Watkins', 'Chappelle', 'Teddy', 'Wimmer', "D'Innocenzo,", 'McCanlies', 'Bergeron', 'Besson', 'Ting', 'Yi,', 'Keong', 'Caroline', 'Gareth', 'Quale', 'Aja', 'Scorsese,', 'Giacomo', 'Jarecki', 'Alejandro', "O'Brien", "D'Innocenzo", 'Zaslove,', 'Metter', 'Malik', 'Foner', 'Dahan', 'Andreasyan', 'Brad', 'Baruchel', 'Zak', 'Whedon', 'Eliza', 'Pellington', 'Donnersmarck', 'DeLuise', 'Ricky', 'Laurence', 'Liman', 'Tappe', 'Wan', 'Pillsbury', 'Álex', 'Jules', 'Herk', 'Piven', 'Miloš', 'Øie', 'Koch', 'Ilya', 'Antonio', 'Krzykowski', 'Clapin', 'Askin', 'Hall,', 'Severin', 'Elkayem', 'Jimbo', 'Ka ...
