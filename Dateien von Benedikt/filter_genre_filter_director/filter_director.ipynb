# %%
import pandas as pd 
import numpy as np 
from ast import literal_eval
from tabulate import tabulate  # Import tabulate for clean table formatting
import itertools

# %%
#q_movies = pd.read_parquet("../tmbd_exports/quality_movs_weighted_rating.parquet")
q_movies = pd.read_parquet("../tmdb_api/tmdb_api_cleaned/movies_cleaned_hard.parquet")

# %%
# Function to get all unique genres in the dataset -> this allows to provide a list of available genres before user input

def get_directors(movies_df):
    unique_directors = set(director.strip() for director in movies_df["director"])
    return sorted(unique_directors)

# Function to filter movies by genre (case-insensitive) -> without this if user wrote 'action' instead of 'Action', no movies would come up 
def filter_movies_by_director(movies_df, selected_director):
    cleaned_director = selected_director.lower().strip()
    director_filter = movies_df["director"].apply(lambda x: cleaned_director in [g.lower().strip() for g in x.split(",")])
    return movies_df.loc[director_filter][0:10] 

# Display available genres
available_directors = get_directors(q_movies)
print("\nAvailable directors:\n" + ", ".join(available_directors) + "\n")

#  Get user input
selected_director = input("Enter a director from the list above: ").strip()

# Step 2: Filter dataset based on input genre
filtered_movies = filter_movies_by_director(q_movies, selected_director)

#  Apply weighted rating function to the filtered dataset
if not filtered_movies.empty:
    print("\nTop 10 Movies in the Selected Genre (Ranked by Weighted Rating):\n")
    print(tabulate(filtered_movies[['title', 'score', 'vote_average', 'vote_count']], 
                   headers="keys", tablefmt="pretty", showindex=False))  # Pretty table format

else:
    print("\nNo movies found in this genre.")
# Out:
# Available directors:
# A.R. Murugadoss, Aamir Khan, Aaron Blaise, Robert Walker, Aaron Hann, Mario Miscione, Aaron Harvey, Aaron Horvath, Peter Rida Michail, Aaron Moorhead, Justin Benson, Aaron Nee, Adam Nee, Aaron Schneider, Aaron Seltzer, Aaron Seltzer, Jason Friedberg, Aaron Sorkin, Abbas Kiarostami, Abby Kohn, Marc Silverstein, Abdellatif Kechiche, Abderrahmane Sissako, Abe Forsythe, Abel Ferrara, Abel Ferry, Adam Alleca, Adam Berg, Adam Brooks, Adam Doench, Lyndale V. Pettus, Cess Silvera, Adam Elliot, Adam Green, Adam MacDonald, Adam Marcus, Adam Mason, Adam McKay, Adam Randall, Adam Rifkin, Adam Robitel, Adam Salky, Adam Schindler, Adam Shankman, Adam Smith, Adam Wingard, Adam Wood, Adele Lim, Aditya Chopra, Aditya Dhar, Adrian Grünberg, Adrian Lyne, Adrienne Shelly, Afonso Poyart, Agnieszka Holland, Agnieszka Wojtowicz-Vosloo, Agnès Jaoui, Agnès Obadia, Agnès Varda, Agnès Varda, JR, Aisling Walsh, Akan Satayev, Aki Kaurismäki, Akifumi Zako, Mitsuo Hashimoto, Akira Kurosawa, Akiva Goldsman, Akiva Schaffer, Akiva Schaffer, Jorma Taccone, Alain Berbérian, Alain Chabat, Alain Desrochers, Alain Gsponer, Alain Guiraudie, Alain Resnais, Alan Ball, Alan J. Pakula, Alan Mak Siu-Fai, Andrew Lau Wai-Keung, Alan Metter, Alan Myerson, Alan Parker, Alan Poul, Alan Rickman, Alan Shapiro, Alan Taylor, Alastair Fothergill, Mark Linfield, Albert Dupontel, Albert Hughes, Albert Hughes, Allen Hughes, Albert Lamorisse, Albert Magnoli, Albert Pintó, Albert Pyun, Albert Uderzo, René Goscinny, Alberto Rodríguez, Aldo Baglio, Morgan Bertacca, Giacomo Poretti, Giovanni Storti, Alejandra Márquez Abella, Alejandro Agresti, Alejandro Amenábar, Alejandro González Iñárritu, Alejandro Hidalgo, Alejandro Jodorowsky, Alejandro Landes, Alejandro Monteverde, Alek Keshishian, Aleksander Bach, Aleksandr Sokurov, Aleksey Balabanov, Aleksey Tsitsilin, Alessandro Genovesi, Alessandro Siani, Alessio Cremonini, Alex Brewer, Benjamin Brewer, Alex Cox, Alex Garland, Alex Gibney, Alex Goyette, Alex Hardcastle, Alex Israel, Alex Kalymnios, Alex Kendrick, Alex Kurtzman, Alex Proyas, Alex Richanbach, Alex Rudzinski, Thomas Kail, Alex Winter, Alex Zamm, Alex van Warmerdam, Alexander Mackendrick, Alexander Payne, Alexander Witt, Alexandra-Therese Keining, Alexandre Aja, Alexandre Astier, Alexandre Astier, Louis Clichy, Alexandre Castagnetti, Alexandre Charlot, Franck Magnier, Alexandre Coffre, Alexandre Lehmann, Alexandre Moratto, Alexandros Avranas, Alexey Sidorov, Alexis Michalik, Alexis Wajsbrot, Damien Macé, Alexs Stadermann, Alfonso Arau, Alfonso Cuarón, Alfonso Gomez-Rejon, Alfred Hitchcock, Alfred Sole, Ali Abbasi, Ali Tabrizi, Alice Filippi, Alice Mathias, Al Campbell, Alice Rohrwacher, Alice Waddington, Alice Winocour, Alice Wu, Aline Brosh McKenna, Alister Grierson, Allan A. Goldstein, Allan Moyle, Allan Ungar, Allen Coulter, Allen Hughes, Allen Hughes, Albert Hughes, Allison Burnett, Allison Liddi-Brown, Alma Har'el, Amber Sealey, Ami Canaan Mann, Amma Asante, Amp Wong, Amp Wong, Zhao Ji, Amy Heckerling, Amy Holden Jones, Amy J. Berg, Amy Poehler, Ana Lily Amirpour, Anand Tucker, Anders Thomas Jensen, Anders Walter, Andrea Arnold, Andrea Berloff, Andrea Di Stefano, Andreas Prochaska, Andrei Konchalovsky, Andrei Tarkovsky, Andrew Adamson, Andrew Adamson, Vicky Jenson, Andrew Bergman, Andrew Bowler, Andrew Currie, Andrew Davis, Andrew Dominik, Andrew Douglas, Andrew Erwin, Jon Erwin, Andrew Fleming, Andrew Goth, Andrew Haigh, Andrew Hyatt, Andrew J. Cohen, Andrew Jarecki, Andrew Knight, Andrew Lau Wai-Keung, Andrew Lau Wai-Keung, Alan Mak Siu-Fai, Andrew Lawrence, Andrew Levitas, Andrew Morahan, Andrew Nackman, Andrew Niccol, Andrew Patterson, Andrew Sipes, Andrew Stanton, Andrew Traucki, Andrew Traucki, David Nerlich, Andrew Waller, Andrey Zvyagintsev, Andrzej Bartkowiak, Andrzej Sekula, Andrzej Żuławski, André Hunebelle, André Pellenz, André Téchiné, André de Toth, André Øvredal, Andrés Baiz, Andy Cadiff, Andy Fickman, Andy Hamilton, Guy Jenkin, Andy Muschietti, Andy Nyman, Jerem ...
# Enter a director from the list above:  Alex Garland
# Top 10 Movies in the Selected Genre (Ranked by Weighted Rating):
#
# +--------------+-------------------+--------------+------------+
# |    title     |       score       | vote_average | vote_count |
# +--------------+-------------------+--------------+------------+
# |  Ex Machina  | 7.53837296749267  |    7.571     |   13417    |
# | Annihilation | 6.386550320449337 |     6.4      |    8740    |
# |     Men      | 6.076495620459885 |    6.104     |    1140    |
# +--------------+-------------------+--------------+------------+
