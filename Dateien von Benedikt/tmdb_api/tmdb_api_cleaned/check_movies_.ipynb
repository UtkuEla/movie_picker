# %% [markdown]
# # Check Contents of parq files

# %%
import pandas as pd
import numpy as np

# %%
# huge Parq file
# movies = pd.read_parquet("movies.parquet")
#movies = pd.read_parquet("../../tmdb_api/tmdb_api_merged/tmdb_api_merged_data.parquet")
movies = pd.read_parquet("../../tmdb_api/tmdb_api_cleaned/movies_cleaned_hard.parquet")

# %%
movies.head(50)
# Out:
#     movie_id     budget                                         genres  \
# 0        278   25000000                                   Drama, Crime
# 1        238    6000000                                   Drama, Crime
# 2        240   13000000                                   Drama, Crime
# 3        424   22000000                            Drama, History, War
# 4     157336  165000000              Adventure, Drama, Science Fiction
# 5        155  185000000                 Drama, Action, Crime, Thriller
# 6        680    8000000                                Thriller, Crime
# 7     496243   11363000                        Comedy, Thriller, Drama
# 8        497   60000000                          Fantasy, Drama, Crime
# 9        129   19000000                     Animation, Family, Fantasy
# 10       122   94000000                     Adventure, Fantasy, Action
# 11       769   25000000                                   Drama, Crime
# ...

# %%
# hard cleaned file
movies_cleaned_hard = pd.read_parquet("movies_cleaned_hard.parquet")
movies_cleaned_hard.head(50)
# Out:
#       movie_id    budget                                         genres  \
# 0          129  19000000                     Animation, Family, Fantasy
# 24       12477   3700000                          Animation, Drama, War
# 31      637920  10000000                                          Drama
# 153     724089         0                                 Romance, Drama
# 68      265177   4900000                                          Drama
# 306      92321         0                    Romance, Animation, Fantasy
# 6       359940  15000000                                   Crime, Drama
# 13        8392   3700000                     Fantasy, Animation, Family
# 218      25237         0                                     Drama, War
# 60      600354   6000000                                          Drama
# 89      762975         0                                 Romance, Drama
# 7          641   4500000                                   Crime, Drama
# ...

# %%
# 5k movie file
movies_5k = pd.read_parquet("../../tmbd_datasets_parquet_ready/tmbd_5000_api-call_merged.parquet")

# %%
movie_id_5k = movies_5k[["movie_id"]]
movie_id_5k.to_csv("../../input/tmdb_api/links_5k.csv", index=False)

# %%
movie_id_5k
# Out:
#       movie_id
# 0        19995
# 1          285
# 2       206647
# 3        49026
# 4        49529
# ...        ...
# 1266     67238
# 1267     72766
# 1268    231617
# 1269    126186
# 1270     25975
#
# [6068 rows x 1 columns]

# %%
movies["keywords"].value_counts()
# Out:
# keywords
# woman director                                                                                                                                                                                                                             15
# duringcreditsstinger                                                                                                                                                                                                                        8
# cinepanettone                                                                                                                                                                                                                               7
# ninja, shounen, anime, adventure                                                                                                                                                                                                            7
# ...
