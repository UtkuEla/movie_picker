# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

#Import TfIdfVectorizer from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel

# %%
q_movies = pd.read_parquet("../tmbd_exports/quality_movs_weighted_rating.parquet")
#Sort movies based on score calculated above
q_movies.shape
# Out:
# (607, 20)

# %%
indices = pd.Series(q_movies.index, index = q_movies["title"])
indices.shape
# Out:
# (607,)

# %%
#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

#Replace NaN with an empty string
q_movies['overview'] = q_movies['overview']#.fillna('')

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(q_movies['overview'])

#Output the shape of tfidf_matrix
tfidf_matrix.shape
# Out:
# (607, 6462)

# %%
# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
cosine_sim.shape
# Out:
# (607, 607)

# %%
# Function that takes in movie title (and a method as for the return-type), 
# as input and outputs most similar movies in form of a datafrme or series

def get_recommendations(title, cosine_sim=cosine_sim, method="series"):

    # Check if movie part of database
    if indices.get(title) == None:
        return("Title not found.")    
        
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    if method == "df":
        # Return the top 10 most similar movies
        return q_movies.iloc[movie_indices]

    return q_movies["title"].iloc[movie_indices]

# %%
# Returns a dataframe object, with moe recommendations
get_recommendations('Ex Machina', method="df")
# Out:
#         budget                                 genres  \
# 516   58000000                                 Comedy
# 18    15000000  Fantasy, Adventure, Animation, Family
# 319  150000000     Adventure, Comedy, Family, Fantasy
# 163  120000000               Adventure, Drama, Action
# 407   30000000                       Horror, Thriller
# 526   82500000        Comedy, Drama, Fantasy, Romance
# 41   180000000                      Animation, Family
# 420   15000000         Crime, Thriller, Horror, Drama
# 537   10000000              Horror, Mystery, Thriller
# 17   170000000     Action, Science Fiction, Adventure
#
#                                               homepage  movie_id  \
# 516                 http://www.theinternshipmovie.com/    116741
# 18              http://movies.disney.com/spirited-away       129
# 319  https://www.warnerbros.com/charlie-and-chocola...       118
# 163                      http://www.lifeofpimovie.com/     87827
# 407         http://www.discoverthecabininthewoods.com/     22970
# 526                                               None      9339
# 41         http://disney.go.com/disneypictures/wall-e/     10681
# 420              http://www.thelasthouseontheleft.com/     18405
# 537                                               None    321258
# 17                         http://marvel.com/guardians    118340
#
#                                               keywords original_language  \
# 516  job interview, loss of job, intern, reference ...                en
# 18   witch, parents kids relationship, magic, twili...                ja
# 319  london england, father son relationship, choco...                en
# 163              ocean, shipwreck, hindu, tiger, faith                en
# 407  cabin, plot twist, cabin in the woods, filmed ...                en
# 526  regret, workaholic, heart attack, architect, d...                en
# 41                                     romantic comedy                en
# 420  lake, rape, kidnapping, psychopath, sadistic, ...                en
# 537  mask, suicide, fire, england, loss of loved on...                en
# 17   marvel comic, spaceship, space, outer space, o...                en
#
#                         original_title  \
# 516                     The Internship
# 18                            千と千尋の神隠し
# 319  Charlie and the Chocolate Factory
# 163                         Life of Pi
chris Pratt, Zoe Saldana, Dave Bautista, Vin D...          James Gunn
#
#      weighted_rating
# 516         6.055339
# 18          7.624982
# 319         6.488032
# 163         6.941891
# 407         6.296397
# 526         6.003972
# 41          7.436359
# 420         6.267339
# 537         5.973976
# 17          7.632664

# %%
# Returns a dataframe object, with moe recommendations
recommendations = get_recommendations('Ex Machina', method="df")
recommendations
# Out:
#         budget                                 genres  \
# 516   58000000                                 Comedy
# 18    15000000  Fantasy, Adventure, Animation, Family
# 319  150000000     Adventure, Comedy, Family, Fantasy
# 163  120000000               Adventure, Drama, Action
# 407   30000000                       Horror, Thriller
# 526   82500000        Comedy, Drama, Fantasy, Romance
# 41   180000000                      Animation, Family
# 420   15000000         Crime, Thriller, Horror, Drama
# 537   10000000              Horror, Mystery, Thriller
# 17   170000000     Action, Science Fiction, Adventure
#
#                                               homepage  movie_id  \
# 516                 http://www.theinternshipmovie.com/    116741
# 18              http://movies.disney.com/spirited-away       129
# 319  https://www.warnerbros.com/charlie-and-chocola...       118
# 163                      http://www.lifeofpimovie.com/     87827
# 407         http://www.discoverthecabininthewoods.com/     22970
# 526                                               None      9339
# 41         http://disney.go.com/disneypictures/wall-e/     10681
# 420              http://www.thelasthouseontheleft.com/     18405
# 537                                               None    321258
# 17                         http://marvel.com/guardians    118340
#
#                                               keywords original_language  \
# 516  job interview, loss of job, intern, reference ...                en
# 18   witch, parents kids relationship, magic, twili...                ja
# 319  london england, father son relationship, choco...                en
# 163              ocean, shipwreck, hindu, tiger, faith                en
# 407  cabin, plot twist, cabin in the woods, filmed ...                en
# 526  regret, workaholic, heart attack, architect, d...                en
# 41                                     romantic comedy                en
# 420  lake, rape, kidnapping, psychopath, sadistic, ...                en
# 537  mask, suicide, fire, england, loss of loved on...                en
# 17   marvel comic, spaceship, space, outer space, o...                en
#
#                         original_title  \
# 516                     The Internship
# 18                            千と千尋の神隠し
# 319  Charlie and the Chocolate Factory
# 163                         Life of Pi
# 407             The Cabin in the Woods
# 526                              Click
# 41                              WALL·E
# 420         The Last House on the Left
# 537                            The Boy
# 17             Guardians of the Galaxy
#
#                                               overview  popularity  \
# 516  Two recently laid-off men in their 40s try to ...    1.551497
# 18   A ten year old girl who wanders away from her ...  118.968562
# 319  A young boy wins a tour through the most magni...   53.905592
# 163  The story of an Indian boy named Pi, a zookeep...   51.328145
# 407  Five college friends spend the weekend at a re...   73.987775
# 526  A workaholic architect finds a universal remot...   41.176631
# 41   WALL·E is the last robot left on an Earth that...   66.390712
# 420  When athletic teen Mari Collingwood opts to ha...    8.672000
# 537  A young American woman takes a job as a nanny ...    7.841000
# 17   Light years from Earth, 26 years after being a...  481.098624
#
#     release_date    revenue  runtime    status  \
# 516   2013-06-07   44000000    119.0  Released
# 18    2001-07-20  274925095    125.0  Released
# 319   2005-07-13  474968763    115.0  Released
# 163   2012-11-20  609016565    127.0  Released
# 407   2012-04-12   66486080     95.0  Released
# 526   2006-06-22  237681299    107.0  Released
# 41    2008-06-22  521311860     98.0  Released
# 420   2009-03-13   32721635    113.0  Released
# 537   2016-01-22   73929392     98.0  Released
# 17    2014-07-30  773328629    121.0  Released
#
#                                                tagline  \
# 516               Hiring them was a brilliant mistake.
# 18      The tunnel led Chihiro to a mysterious town...
# 319                Willy Wonka is semi-sweet and nuts.
# 163                           Believe The Unbelievable
# 407    If you hear a strange sound outside... have sex
# 526  What If You Had A Remote... That Controlled Yo...
# 41                  An adventure beyond the ordinar-E.
# 420  If bad people hurt someone you love, how far w...
# 537                   Every child needs to feel loved.
# 17                         All heroes start somewhere.
#
#                                  title  vote_average  vote_count  \
# 516                     The Internship         6.100        1658
# 18                       Spirited Away         8.300        3840
# 319  Charlie and the Chocolate Factory         6.700        3624
# 163                         Life of Pi         7.200        5797
# 407             The Cabin in the Woods         6.500        2263
# 526                              Click         6.000        2104
# 41                              WALL·E         7.800        6296
# 420         The Last House on the Left         6.500        1780
# 537                            The Boy         5.959        3771
# 17             Guardians of the Galaxy         7.900        9742
#
#                                                   cast            director  \
# 516  Owen Wilson, Vince Vaughn, Rose Byrne, Max Min...          Shawn Levy
# 18   Rumi Hiiragi, Miyu Irino, Mari Natsuki, Takash...      Hayao Miyazaki
# 319  Johnny Depp, Freddie Highmore, David Kelly, An...          Tim Burton
# 163  Suraj Sharma, Irrfan Khan, Ayush Tandon, Gauta...             Ang Lee
# 407  Kristen Connolly, Chris Hemsworth, Anna Hutchi...        Drew Goddard
# 526  Adam Sandler, Kate Beckinsale, Christopher Wal...        Frank Coraci
# 41   Ben Burtt, Elissa Knight, Jeff Garlin, Fred Wi...      Andrew Stanton
# 420  Tony Goldwyn, Monica Potter, Sara Paxton, Garr...      Dennis Iliadis
# 537  Lauren Cohan, Rupert Evans, James Russell, Jim...  William Brent Bell
# 17   Chris Pratt, Zoe Saldana, Dave Bautista, Vin D...          James Gunn
#
#      weighted_rating
# 516         6.055339
# 18          7.624982
# 319         6.488032
# 163         6.941891
# 407         6.296397
# 526         6.003972
# 41          7.436359
# 420         6.267339
# 537         5.973976
# 17          7.632664

# %%
# %%writefile recommender.py

def get_recommendations(title, cosine_sim, indices, q_movies, method="series"):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    movie_indices = [i[0] for i in sim_scores]

    if method == "df":
        return q_movies.iloc[movie_indices]
    return q_movies["title"].iloc[movie_indices]
# Out:
# Writing recommender.py
